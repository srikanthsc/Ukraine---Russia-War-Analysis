# %% [markdown]
# # <p style="padding:10px;background-color:#3d11ed;margin:0;color:#e9c46a;font-family:newtimeroman;font-size:150%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Ukraine Russia War Analysis</p>
#
# <p style="text-align:center; ">
# <img src="https://media.istockphoto.com/videos/russia-ukraine-war-concept-map-animation-video-id1366363020?s=640x640" style='width: 600px; height: 300px;'>
# </p>
#
# <p style="text-align:justify; ">
# The Russo-Ukrainian War is an ongoing war between Russia (together with pro-Russian separatist forces) and Ukraine. It was started by Russia in February 2014 following the Ukrainian Revolution of Dignity, and initially focused on the status of Crimea and the Donbas, internationally recognised as part of Ukraine. The first eight years of the conflict included the Russian annexation of Crimea (2014) and the war in Donbas (2014–2022) between Ukraine and Russian-backed separatists, as well as naval incidents, cyberwarfare and political tensions. Following a Russian military build-up on the Russia–Ukraine border from late 2021, the conflict expanded significantly when Russia launched a full-scale invasion of Ukraine on 24 February 2022.
#
# The invasion caused Europe's largest refugee crisis since World War II, with more than 8.8 million Ukrainians fleeing the country and a third of the population displaced. The invasion also caused global food shortages.
# </p>
#
# <a id='top'></a>
# <div class="list-group" id="list-tab" role="tablist">
# <p style="padding:10px;background-color:#3d11ed;margin:0;color:#e9c46a;font-family:newtimeroman;font-size:130%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Table Of Contents</p>
#
#
# |No  | Contents                                     |No  | Contents                        |
# |:---| :---                                         |:---| :----                           |
# |1   | [<font color="#bc4749"> Importing Libraries</font>](#1) |9   | [<font color="#bc4749"> Air Equipments Destiny](#9)   |
# |2   | [<font color="#bc4749"> About Dataset</font>](#2)                         |10  | [<font color="#bc4749"> Water Equipments Destiny</font>](#10)|
# |3   | [<font color="#bc4749"> Basic Exploration</font>](#3)                     |11  | [<font color="#bc4749"> Field Equipments Destiny</font>](#11)|
# |4   | [<font color="#bc4749"> Dataset Summary</font>](#4)                       |12  | [<font color="#bc4749"> Daywise Destruction</font>](#12)    |
# |5   | [<font color="#bc4749"> Custom Palette For Visualization</font>](#5)      |13  | [<font color="#bc4749"> Cumulative Destruction</font>](#13)  |
# |6   | [<font color="#bc4749"> Directions Of Greatest Loss</font>](#6)           |14  | [<font color="#bc4749"> Overall Destruction</font>](#14)     |
# |7   | [<font color="#bc4749"> Final Dataset For Deeper Exploration</font>](#7)  |15  | [<font color="#bc4749"> Correlation Map</font>](#15)         |
# |8   | [<font color="#bc4749"> Invaders Destiny</font>](#8)                      |16  | [<font color="#bc4749"> Thank You</font>](#16)               |

# %% [markdown]
# <a id="1"></a>
# # <p style="padding:10px;background-color:#3d11ed;margin:0;color:#e9c46a;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Importing Libraries</p>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import folium as F
import warnings
warnings.filterwarnings('ignore')
from wordcloud import WordCloud, STOPWORDS
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [4], line 1
# ----> 1 import pandas as pd
#       2 import matplotlib.pyplot as plt
#       3 import seaborn as sns
#
# ModuleNotFoundError: No module named 'pandas'

# %% [markdown]
# <a id="2"></a>
# # <p style="padding:10px;background-color:#3d11ed;margin:0;color:#e9c46a;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">About Dataset</p>

# %% [markdown]
# This dataset describes **Equipment Loss**, **Death Toll**, **Military Wounded** & **Prisoner** of Russia in 2022 Ukraine-Russia War.
# All data are official and additionally structured. This dataset was created after 7 days of starting the War.
#
# **Acronyms Used :**
# * POW - Prisoner Of War
# * MRL - Multiple Rocket Launcher
# * APC - Armored Personnel Carrier
# * SRBM - Short Range Ballistic Missile

# %%
equipment_dataset = pd.read_csv("../input/2022-ukraine-russian-war/russia_losses_equipment.csv")
personnel_dataset = pd.read_csv("../input/2022-ukraine-russian-war/russia_losses_personnel.csv")

# %% [markdown]
# <a id="3"></a>
# # <p style="padding:10px;background-color:#3d11ed;margin:0;color:#e9c46a;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Basic Exploration</p>

# %%
for col in equipment_dataset.columns:
    print(col)
print("-----------------------------------")
for col in personnel_dataset.columns:
    print(col)
# Out:
# date
# day
# aircraft
# helicopter
# tank
# APC
# field artillery
# MRL
# military auto
# fuel tank
# drone
# naval ship
# anti-aircraft warfare
# special equipment
# mobile SRBM system
# greatest losses direction
# vehicles and fuel tanks
# cruise missiles
# -----------------------------------
# date
# day
# personnel
# personnel*
# POW

# %% [markdown]
# **Let's have a glimpse of equipment dataset.**

# %%
print(f"Shape of The Equipment Dataset : {equipment_dataset.shape}")
print(f"\nGlimpse of The Dataset :")
equipment_dataset.head().style.set_properties(**{"background-color": "#3d11ed","color":"#e9c46a","border": "1.5px solid black"})
# Out:
# Shape of The Equipment Dataset : (261, 18)
#
# Glimpse of The Dataset :
# <style type="text/css">
# ...

# %%
print(f"Informations About Equipment Dataset :\n")
print(equipment_dataset.info())
# Out:
# Informations About Equipment Dataset :
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 261 entries, 2022-02-25 to 2022-11-12
# Data columns (total 19 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   day                        261 non-null    int64
#  1   aircraft                   261 non-null    int64
#  2   helicopter                 261 non-null    int64
#  3   tank                       261 non-null    int64
#  4   APC                        261 non-null    int64
#  5   field artillery            261 non-null    int64
#  6   MRL                        261 non-null    int64
#  7   military auto              261 non-null    float64
#  8   fuel tank                  261 non-null    float64
#  9   drone                      261 non-null    int64
#  10  naval ship                 261 non-null    int64
#  11  anti-aircraft warfare      261 non-null    int64
# ...

# %% [markdown]
# **Let's have a glimpse of personnel dataset.**

# %%
print(f"Shape of The Personnel Dataset : {personnel_dataset.shape}")
print(f"\nGlimpse of The Dataset :")
personnel_dataset.head().style.set_properties(**{"background-color": "#3d11ed","color":"#e9c46a","border": "1.5px solid black"})
# Out:
# Shape of The Personnel Dataset : (261, 5)
#
# Glimpse of The Dataset :
# <style type="text/css">
# #T_6da4c_row0_col0, #T_6da4c_row0_col1, #T_6da4c_row0_col2, #T_6da4c_row0_col3, #T_6da4c_row0_col4, #T_6da4c_row1_col0, #T_6da4c_row1_col1, #T_6da4c_row1_col2, #T_6da4c_row1_col3, #T_6da4c_row1_col4, #T_6da4c_row2_col0, #T_6da4c_row2_col1, #T_6da4c_row2_col2, #T_6da4c_row2_col3, #T_6da4c_row2_col4, #T_6da4c_row3_col0, #T_6da4c_row3_col1, #T_6da4c_row3_col2, #T_6da4c_row3_col3, #T_6da4c_row3_col4, #T_6da4c_row4_col0, #T_6da4c_row4_col1, #T_6da4c_row4_col2, #T_6da4c_row4_col3, #T_6da4c_row4_col4 {
#   background-color: #3d11ed;
#   color: #e9c46a;
#   border: 1.5px solid black;
# }
# </style>
# <table id="T_6da4c_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >date</th>
#       <th class="col_heading level0 col1" >day</th>
#       <th class="col_heading level0 col2" >personnel</th>
# ...

# %%
print(f"Informations About Personnel Dataset :\n")
print(personnel_dataset.info())
# Out:
# Informations About Personnel Dataset :
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 261 entries, 0 to 260
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        261 non-null    object
#  1   day         261 non-null    int64
#  2   personnel   261 non-null    int64
#  3   personnel*  261 non-null    object
#  4   POW         62 non-null     float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 10.3+ KB
# None

# %% [markdown]
# **Let's merge these two datasets and have a glimpse of the resultant dataset.**

# %%
equipment_dataset[["personnel","POW"]] = personnel_dataset[["personnel","POW"]]
print(f"After merging, let's have a glimpse of the dataset.")
equipment_dataset.head().style.set_properties(**{"background-color": "#3d11ed","color":"#e9c46a","border": "1.5px solid black"})
# Out:
# After merging, let's have a glimpse of the dataset.
# <style type="text/css">
# ...

# %%
saved_column = equipment_dataset.tank
print(saved_column)
# Out:
# 0        80
# 1       146
# 2       150
# 3       150
# 4       198
#        ...
# 256    2786
# 257    2801
# 258    2804
# 259    2814
# 260    2838
# Name: tank, Length: 261, dtype: int64

# %% [markdown]
# <a id="4"></a>
# # <p style="padding:10px;background-color:#3d11ed;margin:0;color:#e9c46a;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Dataset Summary</p>

# %%
print(f"Summary Of The Dataset :")
equipment_dataset.describe().style.set_properties(**{"background-color": "#3d11ed","color":"#e9c46a","border": "1.5px solid black"})
# Out:
# Summary Of The Dataset :
# <style type="text/css">
# ...

# %%
equipment_dataset.describe(include=object).T.style.set_properties(**{"background-color": "#3d11ed","color":"#e9c46a","border": "1.5px solid black"})
# Out:
# <style type="text/css">
# #T_1d8e0_row0_col0, #T_1d8e0_row0_col1, #T_1d8e0_row0_col2, #T_1d8e0_row0_col3, #T_1d8e0_row1_col0, #T_1d8e0_row1_col1, #T_1d8e0_row1_col2, #T_1d8e0_row1_col3 {
#   background-color: #3d11ed;
#   color: #e9c46a;
#   border: 1.5px solid black;
# }
# </style>
# <table id="T_1d8e0_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >count</th>
#       <th class="col_heading level0 col1" >unique</th>
#       <th class="col_heading level0 col2" >top</th>
#       <th class="col_heading level0 col3" >freq</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1d8e0_level0_row0" class="row_heading level0 row0" >date</th>
#       <td id="T_1d8e0_row0_col0" class="data row0 col0" >261</td>
#       <td id="T_1d8e0_row0_col1" class="data row0 col1" >261</td>
#       <td id="T_1d8e0_row0_col2" class="data row0 col2" >2022-02-25</td>
# ...

# %% [markdown]
# <a id="5"></a>
# # <p style="padding:10px;background-color:#3d11ed;margin:0;color:#e9c46a;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Custom Palette For Visualization</p>

# %%
sns.set_style("white")
sns.set(rc={"axes.facecolor":"#f2e2ba","figure.facecolor":"#f2e2ba"})
sns.set_context("poster",font_scale = .7)
palette = ["#5f0f40","#9a031e","#fb8b24","#7C7C7C","#e36414","#0f4c5c","#FFC300"]
palette_ex = ["#071e22","#1d7874","#679289","#f4c095","#ee2e31","#ffb563","#918450","#f85e00","#a41623","#9a031e","#d6d6d6","#ffee32","#333533","#ffd100","#202020","#B7094C"]
pal = ["#f94144","#f3722c","#f8961e","#f9844a","#f9c74f","#90be6d","#43aa8b","#4d908e","#577590","#277da1"]

# sns.palplot(sns.color_palette(palette))
# sns.palplot(sns.color_palette(palette_ex))
# sns.palplot(sns.color_palette(pal))
# plt.show()

# %% [markdown]
# <a id="6"></a>
# # <p style="padding:10px;background-color:#3d11ed;margin:0;color:#e9c46a;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Directions Of Greatest Loss</p>
#
# Let's extract all the directions separately and correct wrongly labelled entries.

# %%
great_loss = equipment_dataset[["greatest losses direction"]]
great_loss["greatest losses direction"].replace(np.nan,"NA",inplace=True)
great_loss = great_loss[great_loss["greatest losses direction"].isin(["NA"])==False]
great_loss["greatest losses direction"] = great_loss["greatest losses direction"].str.split(", | , | ,| and ")
great_loss = great_loss.explode("greatest losses direction")
great_loss.replace(to_replace = ["Zaporizhzhya","Slov'yansʹk"], value = ["Zaporizhzhia","Sloviansk"],inplace=True)


print(f'\nGreat losses happened {great_loss.shape[0]} times in {len(great_loss["greatest losses direction"].unique())} different directions.')
print(f'Great losses directions are :\n\n{great_loss["greatest losses direction"].unique()}')

print(f'\nOccurances of direction-wise losses :')
great_loss["greatest losses direction"].value_counts().rename_axis("Greatest Losses Directions").to_frame("Total").T.style.set_properties(**{"background-color": "#3d11ed","color":"#e9c46a","border": "1.5px solid black"})
# Out:
# Great losses happened 286 times in 16 different directions.
# Great losses directions are :
#
# ['Sievierodonetsk' 'Kurakhove' 'Izyum' 'Zaporizhzhia' 'Novopavlivsk'
#  'Popasna' 'Lyman' 'Slobozhanskyi' 'Avdiivka' 'Bakhmut' 'Sloviansk'
#  'Kryvyi Rih' 'Kharkiv' 'Kramatorsk' 'Donetsk' 'Mykolaiv']
#
# Occurances of direction-wise losses :
# <style type="text/css">
# #T_8d7a7_row0_col0, #T_8d7a7_row0_col1, #T_8d7a7_row0_col2, #T_8d7a7_row0_col3, #T_8d7a7_row0_col4, #T_8d7a7_row0_col5, #T_8d7a7_row0_col6, #T_8d7a7_row0_col7, #T_8d7a7_row0_col8, #T_8d7a7_row0_col9, #T_8d7a7_row0_col10, #T_8d7a7_row0_col11, #T_8d7a7_row0_col12, #T_8d7a7_row0_col13, #T_8d7a7_row0_col14, #T_8d7a7_row0_col15 {
#   background-color: #3d11ed;
#   color: #e9c46a;
#   border: 1.5px solid black;
# }
# </style>
# <table id="T_8d7a7_">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Greatest Losses Directions</th>
#       <th class="col_heading level0 col0" >Bakhmut</th>
# ...

# %%
plt.subplots(figsize=(20, 8))
p=sns.countplot(x = great_loss["greatest losses direction"], order = great_loss["greatest losses direction"].value_counts(ascending=False).index[:10],palette=pal, saturation=1, edgecolor = "#1c1c1c", linewidth = 3)
p.axes.set_title("\nDirectionwise Occurances\n",fontsize=25)
plt.ylabel("Total Occurances",fontsize=20)
plt.xlabel("\nDirections Of Greatest Loss",fontsize=20)
plt.xticks(rotation=90)
for container in p.containers:
    p.bar_label(container,label_type = "center",padding = 10,size = 25,color = "black",rotation = 0,
    bbox={"boxstyle": "round", "pad": 0.2, "facecolor": "orange", "edgecolor": "white", "linewidth" : 2, "alpha": 1})

    
sns.despine(left=True, bottom=True)
plt.show()

# %% [markdown]
# **Insights:**
#
# * **Donetsk** is being attacked heavily followed by **Bakhmut**, **Kramatorsk**, **Kryvyi Rih** and other directions.
# * Frequencies of attacking in **Popasna** and **Slobozhanskyi** directions are minimum.

# %% [markdown]
# <br><b>Ukraine map :</b></br>

# %%
ukraine_lat = 48.383022 
ukraine_long = 31.1828699
ukraine_map = F.Map(location=[ukraine_lat, ukraine_long], tiles="Stamen Terrain", zoom_start=6.49)

Kyiv =  F.map.FeatureGroup()
Bakhmut = F.map.FeatureGroup()
Donetsk = F.map.FeatureGroup()
Kramatorsk=F.map.FeatureGroup()
Kryvyi_Rih=F.map.FeatureGroup()
Avdiivka = F.map.FeatureGroup()
Kurakhove = F.map.FeatureGroup()
Slovyansk = F.map.FeatureGroup()
Lyman = F.map.FeatureGroup()
Zaporizhzhia = F.map.FeatureGroup()
Izyum = F.map.FeatureGroup()

Kyiv_lat = 50.4501
Kyiv_long = 30.5234
Bakhmut_lat =48.5987
Bakhmut_long =37.9980
Donetsk_lat =48.0159
Donetsk_long =37.8028
Kramatorsk_lat =48.7390
Kramatorsk_long = 37.5844
Kryvyi_Rih_lat = 47.9105
Kryvyi_Rih_long = 33.3918
Avdiivka_lat = 48.1366
Avdiivka_long = 37.7491
Kurakhove_lat = 47.9866
Kurakhove_long = 37.2907
Slovyansk_lat = 48.8532
Slovyansk_long = 37.6053
Lyman_lat = 48.9898
Lyman_long = 37.8050
Zaporizhzhia_lat = 47.8388
Zaporizhzhia_long = 35.1396
Izyum_lat = 49.2121
Izyum_long = 37.2665

Kyiv.add_child(F.features.CircleMarker([Kyiv_lat,Kyiv_long], radius=5, color="red", fill_color="blue"))
Bakhmut.add_child(F.features.CircleMarker([Bakhmut_lat,Bakhmut_long], radius=5, color="red", fill_color="blue"))
Donetsk.add_child(F.features.CircleMarker([Donetsk_lat,Donetsk_long], radius=5, color="red", fill_color="blue"))
Kramatorsk.add_child(F.features.CircleMarker([Kramatorsk_lat,Kramatorsk_long], radius=5, color="red", fill_color="blue"))
Kryvyi_Rih.add_child(F.features.CircleMarker([Kryvyi_Rih_lat,Kryvyi_Rih_long], radius=5, color="red", fill_color="blue"))
Avdiivka.add_child(F.features.CircleMarker([Avdiivka_lat,Avdiivka_long], radius=5, color="red", fill_color="blue"))
Kurakhove.add_child(F.features.CircleMarker([Kurakhove_lat,Kurakhove_long], radius=5, color="red", fill_color="blue"))
Slovyansk.add_child(F.features.CircleMarker([Slovyansk_lat,Slovyansk_long], radius=5, color="red", fill_color="blue"))
Lyman.add_child(F.features.CircleMarker([Lyman_lat,Lyman_long], radius=5, color="red", fill_color="blue"))
Zaporizhzhia.add_child(F.features.CircleMarker([Zaporizhzhia_lat,Zaporizhzhia_long], radius=5, color="red", fill_color="blue"))
Izyum.add_child(F.features.CircleMarker([Izyum_lat,Izyum_long], radius=5, color="red", fill_color="blue"))
ukraine_map.add_child(Kyiv)

F.Marker([Kyiv_lat,Kyiv_long], popup="Ukraine's Capital City").add_to(ukraine_map)
F.Marker([Bakhmut_lat,Bakhmut_long], popup="Ukraine's City").add_to(ukraine_map)
F.Marker([Donetsk_lat,Donetsk_long], popup="Ukraine's City").add_to(ukraine_map)
F.Marker([Kramatorsk_lat,Kramatorsk_long], popup="Ukraine's City").add_to(ukraine_map)
F.Marker([Kryvyi_Rih_lat,Kryvyi_Rih_long], popup="Ukraine's City").add_to(ukraine_map)
F.Marker([Avdiivka_lat,Avdiivka_long], popup="Ukraine's City").add_to(ukraine_map)
F.Marker([Kurakhove_lat,Kurakhove_long], popup="Ukraine's City").add_to(ukraine_map)
F.Marker([Slovyansk_lat,Slovyansk_long], popup="Ukraine's City").add_to(ukraine_map)
F.Marker([Lyman_lat,Lyman_long], popup="Ukraine's City").add_to(ukraine_map)
F.Marker([Zaporizhzhia_lat,Zaporizhzhia_long], popup="Ukraine's City").add_to(ukraine_map)
F.Marker([Izyum_lat,Izyum_long], popup="Ukraine's City").add_to(ukraine_map)
print('Navigable Map')
ukraine_map
# Out:
# Navigable Map
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# <a id="7"></a>
# # <p style="padding:10px;background-color:#3d11ed;margin:0;color:#e9c46a;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Final Dataset For Deeper Exploration</p>

# %% [markdown]
# Let's drop the **"date"** and **"greatest losses direction"** columns from the final dataset as we don't need these colummns anymore for upcoming explorations. And merge **"military auto"**, **"fuel tank"** and **"vehicles and fuel tanks"** columns as these two columns were merged into **"vehicles and fuel tanks"** since 2022-05-01.

# %%
war_data = equipment_dataset[:]
war_data["vehicles and fuel tanks"] = war_data[["military auto","fuel tank","vehicles and fuel tanks"]].sum(axis=1)
war_data.drop(columns=["date","greatest losses direction","military auto","fuel tank"],inplace=True)
print(f"After processing, let's have a glimpse of the dataset.")
war_data.head(10).style.set_properties(**{"background-color": "#3d11ed","color":"#e9c46a","border": "1.5px solid black"})
# Out:
# After processing, let's have a glimpse of the dataset.
# <style type="text/css">
# ...

# %%
print("Null Values Of The Dataset :")
war_data.isna().sum().to_frame().T.style.set_properties(**{"background-color": "#3d11ed","color":"#e9c46a","border": "1.5px solid black"})
# Out:
# Null Values Of The Dataset :
# <style type="text/css">
# #T_b6ac1_row0_col0, #T_b6ac1_row0_col1, #T_b6ac1_row0_col2, #T_b6ac1_row0_col3, #T_b6ac1_row0_col4, #T_b6ac1_row0_col5, #T_b6ac1_row0_col6, #T_b6ac1_row0_col7, #T_b6ac1_row0_col8, #T_b6ac1_row0_col9, #T_b6ac1_row0_col10, #T_b6ac1_row0_col11, #T_b6ac1_row0_col12, #T_b6ac1_row0_col13, #T_b6ac1_row0_col14, #T_b6ac1_row0_col15 {
#   background-color: #3d11ed;
#   color: #e9c46a;
#   border: 1.5px solid black;
# }
# </style>
# <table id="T_b6ac1_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >day</th>
#       <th class="col_heading level0 col1" >aircraft</th>
#       <th class="col_heading level0 col2" >helicopter</th>
#       <th class="col_heading level0 col3" >tank</th>
#       <th class="col_heading level0 col4" >APC</th>
#       <th class="col_heading level0 col5" >field artillery</th>
#       <th class="col_heading level0 col6" >MRL</th>
# ...

# %% [markdown]
# So we can see there are some null values for **"special equipment"**, **"mobile SRBM system"** and **"cruise missiles"** columns of the dataset. Let's replace the null values with **"0"** and check if there exists any null values yet and replacing null values of **"POW"** by **"496"** as it is in cumulative sum format.

# %%
war_data["POW"].fillna(method ="ffill", inplace = True)
war_data.replace(np.nan,0,inplace=True)
print("After Processing, Null Values Of The Dataset :")
war_data.isna().sum().to_frame().T.style.set_properties(**{"background-color": "#3d11ed","color":"#e9c46a","border": "1.5px solid black"})
# Out:
# After Processing, Null Values Of The Dataset :
# <style type="text/css">
# #T_3fc8b_row0_col0, #T_3fc8b_row0_col1, #T_3fc8b_row0_col2, #T_3fc8b_row0_col3, #T_3fc8b_row0_col4, #T_3fc8b_row0_col5, #T_3fc8b_row0_col6, #T_3fc8b_row0_col7, #T_3fc8b_row0_col8, #T_3fc8b_row0_col9, #T_3fc8b_row0_col10, #T_3fc8b_row0_col11, #T_3fc8b_row0_col12, #T_3fc8b_row0_col13, #T_3fc8b_row0_col14, #T_3fc8b_row0_col15 {
#   background-color: #3d11ed;
#   color: #e9c46a;
#   border: 1.5px solid black;
# }
# </style>
# <table id="T_3fc8b_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >day</th>
#       <th class="col_heading level0 col1" >aircraft</th>
#       <th class="col_heading level0 col2" >helicopter</th>
#       <th class="col_heading level0 col3" >tank</th>
#       <th class="col_heading level0 col4" >APC</th>
#       <th class="col_heading level0 col5" >field artillery</th>
#       <th class="col_heading level0 col6" >MRL</th>
# ...

# %%
equipment_dataset.fillna(0, inplace=True)
"""equipment_dataset.set_index('date', inplace=True)"""
daily_total_equip_loss = equipment_dataset.reset_index('date')
daily_total_equip_loss.drop(columns={'date'}, inplace=True)
daily_total_equip_loss.set_index('day', inplace=True)

# Create new dataframe for graph object
daily_total_equip_loss['Daily Total Equipment Loss'] = pd.DataFrame(daily_total_equip_loss.sum(axis=1))
daily_total_equip_loss[['Daily Total Equipment Loss']]

# Get the most recent loss data
total = int(daily_total_equip_loss.iloc[-1: , -1:].values)

# gather data pertaining to the total equipment lost and generate a count of the equipment lost by type
total_loss = daily_total_equip_loss.iloc[-1: , :-1]
total_loss.reset_index(inplace=True)
total_loss = pd.DataFrame(total_loss.drop('day', axis=1).transpose()).reset_index()
total_loss.rename(columns={'index':'Equipment', 0:'Count'}, inplace=True)
total_loss.set_index('Equipment', inplace=True)
total_loss.sort_values(by='Count', inplace=True)

total_loss
word_string=""
max_words = total_loss.mean()/2
for equipment in total_loss.index:
     times_repeat = int(total_loss.loc[equipment, 'Count']/total * max_words)
     word_string = word_string.upper() + ((equipment + " ") * times_repeat)

# create word cloud
word_cloud = WordCloud(background_color = 'white').generate(word_string)

# Display cloud
plt.figure(figsize=(20,6))
plt.imshow(word_cloud, interpolation='bessel')
plt.title('Most Lost Russian Equipment by Type', fontweight='bold', color='black', backgroundcolor='yellow')
plt.axis('off')


plt.show()

# %% [markdown]
# <a id="8"></a>
# # <p style="padding:10px;background-color:#3d11ed;margin:0;color:#e9c46a;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Invaders Destiny</p>
#
# We can see all the values of the dataset are recorded in column-wise cumulative sum format. Let's create a new dataset named **"person_data"** and reformat the datas in daywise record format.

# %%
person_data = war_data[["day","personnel","POW"]]
person_data[["personnel","POW"]] = person_data[["personnel","POW"]].diff().fillna(person_data[["personnel","POW"]])
person_data.set_index("day", drop=True, inplace=True)

print("After processing, let's have a glimpse of the dataset :")
person_data.head(20).astype(int).T.style.set_properties(**{"background-color": "#3d11ed","color":"#e9c46a","border": "1.5px solid black"})
# Out:
# After processing, let's have a glimpse of the dataset :
# <style type="text/css">
# #T_724bf_row0_col0, #T_724bf_row0_col1, #T_724bf_row0_col2, #T_724bf_row0_col3, #T_724bf_row0_col4, #T_724bf_row0_col5, #T_724bf_row0_col6, #T_724bf_row0_col7, #T_724bf_row0_col8, #T_724bf_row0_col9, #T_724bf_row0_col10, #T_724bf_row0_col11, #T_724bf_row0_col12, #T_724bf_row0_col13, #T_724bf_row0_col14, #T_724bf_row0_col15, #T_724bf_row0_col16, #T_724bf_row0_col17, #T_724bf_row0_col18, #T_724bf_row0_col19, #T_724bf_row1_col0, #T_724bf_row1_col1, #T_724bf_row1_col2, #T_724bf_row1_col3, #T_724bf_row1_col4, #T_724bf_row1_col5, #T_724bf_row1_col6, #T_724bf_row1_col7, #T_724bf_row1_col8, #T_724bf_row1_col9, #T_724bf_row1_col10, #T_724bf_row1_col11, #T_724bf_row1_col12, #T_724bf_row1_col13, #T_724bf_row1_col14, #T_724bf_row1_col15, #T_724bf_row1_col16, #T_724bf_row1_col17, #T_724bf_row1_col18, #T_724bf_row1_col19 {
#   background-color: #3d11ed;
#   color: #e9c46a;
#   border: 1.5px solid black;
# }
# ...

# %%
print(f'Total amount of dead invaders : {person_data["personnel"].sum().astype(int)}')
print(f'Total amount of prisoners : {person_data["POW"].sum().astype(int)}')
# Out:
# Total amount of dead invaders : 79400
# Total amount of prisoners : 496

# %%
plt.subplots(figsize=(12, 12))

labels = "Dead Personnel","Prisoner"
size = 0.5

wedges, texts, autotexts = plt.pie([person_data["personnel"].sum(),
                                    person_data["POW"].sum()],
                                    explode = (0,0),
                                    textprops=dict(size= 20, color= "white"),
                                    autopct="%.2f%%", 
                                    pctdistance = 0.75,
                                    radius=1, 
                                    colors = ["#bc4749","#FFC300"],
                                    # labels = labels, # labeldistance = 1.05,
                                    shadow = True,
                                    wedgeprops=dict(width = size, edgecolor = "#1c1c1c", linewidth = 4),
                                    startangle = 1)

plt.legend(wedges, labels, title="Category",loc="center left",bbox_to_anchor=(1, 0, 0.5, 1), edgecolor = "#1c1c1c")
plt.title("\nDestiny Of Invaders",fontsize=20)
plt.show()

# %%
plt.subplots(figsize=(20, 8))
p = sns.histplot(person_data["personnel"],color="#3d11ed",kde=True,bins=50,alpha=1,fill=True,edgecolor=palette_ex[14])
p.axes.lines[0].set_color(palette[6])
p.axes.set_title("\nPersonnel Death Quantity Distribution\n",fontsize=25)
plt.ylabel("Count",fontsize=20)
plt.xlabel("\nPersonnel Amount",fontsize=20)
sns.despine(left=True, bottom=True)

plt.show()

# %%
print("Frequency of prisoners in a day :")
person_data[person_data["POW"]>0]["POW"].astype(int).value_counts().rename_axis("Prisoner").to_frame("Occurance").T.style.set_properties(**{"background-color": "#3d11ed","color":"#e9c46a","border": "1.5px solid black"})
# Out:
# Frequency of prisoners in a day :
# <style type="text/css">
# #T_44c76_row0_col0, #T_44c76_row0_col1, #T_44c76_row0_col2, #T_44c76_row0_col3, #T_44c76_row0_col4, #T_44c76_row0_col5, #T_44c76_row0_col6, #T_44c76_row0_col7, #T_44c76_row0_col8, #T_44c76_row0_col9, #T_44c76_row0_col10, #T_44c76_row0_col11, #T_44c76_row0_col12, #T_44c76_row0_col13 {
#   background-color: #3d11ed;
#   color: #e9c46a;
#   border: 1.5px solid black;
# }
# </style>
# <table id="T_44c76_">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Prisoner</th>
#       <th class="col_heading level0 col0" >16</th>
#       <th class="col_heading level0 col1" >1</th>
#       <th class="col_heading level0 col2" >9</th>
#       <th class="col_heading level0 col3" >7</th>
#       <th class="col_heading level0 col4" >200</th>
#       <th class="col_heading level0 col5" >27</th>
#       <th class="col_heading level0 col6" >25</th>
#       <th class="col_heading level0 col7" >76</th>
# ...

# %%
plt.subplots(figsize=(20, 8))
p = sns.histplot(person_data[person_data["POW"]>0]["POW"],color="#fca311",kde=True,bins=30,alpha=1,fill=True,edgecolor=palette_ex[14])
p.axes.lines[0].set_color("#bc4749")
p.axes.set_title("\nPrisoner Of War Quantity Distribution\n",fontsize=25)
plt.ylabel("Count",fontsize=20)
plt.xlabel("\nPrisoner Amount",fontsize=20)

sns.despine(left=True, bottom=True)
plt.show()

# %% [markdown]
# **Insights:**
#
# * Total amount of dead invaders are 59080 which is the fate of 99.17% of captured invaders
# * Total amount of prisoners are 496 which is the fate of 0.83% of captured invaders
# * Less than 500 invaders were being killed in a day more frequently
# * Less than 25 invaders were being sent to prison in a day more frequently

# %% [markdown]
# <a id="9"></a>
# # <p style="padding:10px;background-color:#3d11ed;margin:0;color:#e9c46a;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Air Equipments Destiny</p>
#
# Let's explore overall air equipments destructions. For this we will count **aircraft**, **helicopter**, **drone** and **mobile SRBM system** as air equipments.

# %%
air_data = war_data[["day","aircraft","helicopter","drone","mobile SRBM system"]]
air_data[["aircraft","helicopter","drone","mobile SRBM system"]] = air_data[["aircraft","helicopter","drone","mobile SRBM system"]].diff().fillna(air_data[["aircraft","helicopter","drone","mobile SRBM system"]])
air_data.set_index("day" , drop=True, inplace =True)

print("Day-wise destructions of air equipments :")
air_data.head(25).astype(int).T.style.set_properties(**{"background-color": "#3d11ed","color":"#e9c46a","border": "1.5px solid black"})
# Out:
# Day-wise destructions of air equipments :
# <style type="text/css">
# ...

# %%
_, axs = plt.subplots(2,2,figsize=(20,10),sharex=True)
plt.tight_layout(pad=4.0)

sns.lineplot(x="day",y="aircraft",data=air_data,ax=axs[0,0],color=palette[5])
axs[0,0].set_title("Aircraft\n",fontsize=25)
axs[0,0].set_xlabel("Days",fontsize=20)
axs[0,0].set_ylabel("Quantity",fontsize=20)

sns.lineplot(x="day",y="helicopter",data=air_data,ax=axs[0,1],color=palette[6])
axs[0,1].set_title("Helicopter\n",fontsize=25)
axs[0,1].set_xlabel("Days",fontsize=20)
axs[0,1].set_ylabel("Quantity",fontsize=20)

sns.lineplot(x="day",y="drone",data=air_data,ax=axs[1,0],color=palette[0])
axs[1,0].set_title("Drone\n",fontsize=25)
axs[1,0].set_xlabel("\nDays",fontsize=20)
axs[1,0].set_ylabel("Quantity",fontsize=20)

sns.lineplot(x="day",y="mobile SRBM system",data=air_data[air_data["mobile SRBM system"]>= 0],ax=axs[1,1],color=palette[1])
axs[1,1].set_title("Mobile SRBM System\n",fontsize=25)
axs[1,1].set_xlabel("\nDays",fontsize=20)
axs[1,1].set_ylabel("Quantity",fontsize=20)

plt.suptitle("Daywise Air Equipments Destruction",fontsize=30, y=1.05)

sns.despine(left=True, bottom=True)
plt.show()

# %%
plt.subplots(figsize=(12, 12))

labels = "Aircraft","Helicopter","Drone"
size = 0.5

wedges, texts, autotexts = plt.pie([air_data["aircraft"].sum(),
                                    air_data["helicopter"].sum(),
                                    air_data["drone"].sum()],
                                    explode = (0,0,0),
                                    textprops=dict(size= 20, color= "white"),
                                    autopct="%.2f%%", 
                                    pctdistance = 0.70,
                                    radius=.9, 
                                    colors = ["#a3a380","#fee440","#bc4749"], 
                                    # labels = labels, # labeldistance = 1.05,
                                    shadow = True,
                                    wedgeprops=dict(width = size, edgecolor = "#1c1c1c", linewidth = 4),
                                    startangle = -67)

plt.legend(wedges, labels, title="Category",loc="center left",bbox_to_anchor=(1, 0, 0.5, 1), edgecolor = "#1c1c1c")
plt.title("\nAir Equipments Destruction",fontsize=20)
plt.show()

# %% [markdown]
# **Insights:**
#
# * As **Mobile SRBM System** occupies 0% of a wedge in pie chart, so it's excluded for this exploration
# * Among the destroyed air equipments **67.23%** is **drone**, **17.69%** is **aircraft** and **15.08%** is **helicopter**

# %% [markdown]
# <a id="10"></a>
# # <p style="padding:10px;background-color:#3d11ed;margin:0;color:#e9c46a;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Water Equipments Destiny</p>
#
# Let's explore overall water equipments destructions. For this we will count **naval ship** and **cruise missiles** as water equipments.

# %%
water_data = war_data[["day","naval ship","cruise missiles"]]
water_data[["naval ship","cruise missiles"]] = water_data[["naval ship","cruise missiles"]].diff().fillna(water_data[["naval ship","cruise missiles"]])
water_data.set_index("day" , drop=True, inplace =True)

print("Day-wise destructions of water equipments :")
water_data.head(25).astype(int).T.style.set_properties(**{"background-color": "#3d11ed","color":"#e9c46a","border": "1.5px solid black"})
# Out:
# Day-wise destructions of water equipments :
# <style type="text/css">
# ...

# %%
_, axs = plt.subplots(1,2,figsize=(20,5),sharex=True)
plt.tight_layout(pad=4.0)

sns.lineplot(x="day",y="naval ship",data=water_data,ax=axs[0],color="#bc4749")
axs[0].set_title("\nNaval Ship\n",fontsize=25)
axs[0].set_xlabel("\nDays",fontsize=20)
axs[0].set_ylabel("Quantity",fontsize=20)

sns.lineplot(x="day",y="cruise missiles",data=water_data,ax=axs[1],color=palette[6])
axs[1].set_title("\nCruise Missile\n",fontsize=25)
axs[1].set_xlabel("\nDays",fontsize=20)
axs[1].set_ylabel("Quantity",fontsize=20)

plt.suptitle("Daywise Water Equipments Destruction",fontsize=30, y=1.1)
sns.despine(left=True, bottom=True)
plt.show()

# %%
plt.subplots(figsize=(12, 12))

labels = "Naval Ship","Cruise Missile"
size = 0.5

wedges, texts, autotexts = plt.pie([water_data["naval ship"].sum(),
                                    water_data["cruise missiles"].sum()],
                                    explode = (0,0),
                                    textprops=dict(size= 20, color= "white"),
                                    autopct="%.2f%%", 
                                    pctdistance = 0.72,
                                    radius=.9, 
                                    colors = ["#FFC300","#bc4749"], 
                                    # labels = labels, # labeldistance = 1.05,
                                    shadow = True,
                                    wedgeprops=dict(width = size, edgecolor = "#1c1c1c", 
                                    linewidth = 4),
                                    startangle = -13)

plt.legend(wedges, labels, title="Category",loc="center left",bbox_to_anchor=(1, 0, 0.5, 1), edgecolor = "#1c1c1c")
plt.title("\nWater Equipments Destruction",fontsize=20)
plt.show()

# %% [markdown]
# **Insights:**
#
# * Among the destroyed water equipments **94.25%** is **Cruise Missile** and **5.75%** is **Naval Ship**

# %% [markdown]
# <a id="11"></a>
# # <p style="padding:10px;background-color:#3d11ed;margin:0;color:#e9c46a;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Field Equipments Destiny</p>
#
# Let's explore overall field equipments destructions. For this we will count **tank**, **APC**, **MRL**, **field artillery**, **anti-aircraft warfare** and **vehicles and fuel tanks** as field equipments.
# As **vehicles and fuel tanks** has negative values, let's set them to zero.

# %%
field_data = war_data[["day","tank","APC","MRL","field artillery","anti-aircraft warfare","vehicles and fuel tanks"]]
field_data[["tank","APC","MRL","field artillery","anti-aircraft warfare","vehicles and fuel tanks"]] = field_data[["tank","APC","MRL","field artillery","anti-aircraft warfare","vehicles and fuel tanks"]].diff().fillna(field_data[["tank","APC","MRL","field artillery","anti-aircraft warfare","vehicles and fuel tanks"]])
field_data[field_data["vehicles and fuel tanks"] < 0]["vehicles and fuel tanks"] = 0
field_data.set_index("day" , drop=True, inplace =True)

print("Day-wise destructions of field equipments :")
field_data.head(25).astype(int).T.style.set_properties(**{"background-color": "#3d11ed","color":"#e9c46a","border": "1.5px solid black"})
# Out:
# Day-wise destructions of field equipments :
# <style type="text/css">
# ...

# %%
_, axs = plt.subplots(2,3,figsize=(25,12),sharex=True)
plt.tight_layout(pad=4.0)

sns.lineplot(x="day",y="tank",data=field_data,ax=axs[0,0],color=palette[5])
axs[0,0].set_title("\nTank\n",fontsize=25)
axs[0,0].set_xlabel("Days",fontsize=20)
axs[0,0].set_ylabel("Quantity",fontsize=20)

sns.lineplot(x="day",y="APC",data=field_data,ax=axs[0,1],color=palette[6])
axs[0,1].set_title("\nArmored Personnel Carrier\n",fontsize=25)
axs[0,1].set_xlabel("Days",fontsize=20)
axs[0,1].set_ylabel("Quantity",fontsize=20)

sns.lineplot(x="day",y="vehicles and fuel tanks",data=field_data,ax=axs[0,2],color=palette[3])
axs[0,2].set_title("\nVehicle and Fuel Tank\n",fontsize=25)
axs[0,2].set_xlabel("Days",fontsize=20)
axs[0,2].set_ylabel("Quantity",fontsize=20)

sns.lineplot(x="day",y="MRL",data=field_data,ax=axs[1,0],color=palette[0])
axs[1,0].set_title("\nMultiple Rocket Launcher\n",fontsize=25)
axs[1,0].set_xlabel("\nDays",fontsize=20)
axs[1,0].set_ylabel("Quantity",fontsize=20)

sns.lineplot(x="day",y="anti-aircraft warfare",data=field_data,ax=axs[1,1],color=palette[2])
axs[1,1].set_title("\nAnti Aircraft Warfare\n",fontsize=25)
axs[1,1].set_xlabel("\nDays",fontsize=20)
axs[1,1].set_ylabel("Quantity",fontsize=20)

sns.lineplot(x="day",y="field artillery",data=field_data,ax=axs[1,2],color=palette[1])
axs[1,2].set_title("\nField Artillery Destruction\n",fontsize=25)
axs[1,2].set_xlabel("\nDays",fontsize=20)
axs[1,2].set_ylabel("Quantity",fontsize=20)

# plt.delaxes(axs[2,0])
# plt.delaxes(axs[2,2])
plt.suptitle("Daywise Field Equipments Destruction",fontsize=30, y=1.05)
sns.despine(left=True, bottom=True)
plt.show()

# %%
plt.subplots(figsize=(12, 12))

labels = "Armored Personnel Carrier","Vehicle And Fuel Tank","Tank","Field Artillery","Multiple Rocket Launcher","Anti Aircraft Warfare"
size = 0.5

wedges, texts, autotexts = plt.pie([field_data["APC"].sum(),
                                    field_data["vehicles and fuel tanks"].sum(),
                                    field_data["tank"].sum(),
                                    field_data["field artillery"].sum(),
                                    field_data["MRL"].sum(),
                                    field_data["anti-aircraft warfare"].sum()],
                                    explode = (0,0,0,0,0,0),
                                    textprops=dict(size= 20, color= "white"),
                                    autopct="%.2f%%", 
                                    pctdistance = 0.75,
                                    radius=1, 
                                    colors = ["#bc4749","#585123","#eec170","#db7c26","#d8572a","#f7b538"],
                                    # labels = labels, # labeldistance = 1.05,
                                    shadow = True,
                                    wedgeprops=dict(width = size, edgecolor = "#1c1c1c", linewidth = 4),
                                    startangle = 0)

plt.legend(wedges, labels, title="Category",loc="center left",bbox_to_anchor=(1, 0, 0.5, 1),edgecolor = "#1c1c1c")
plt.title("\nField Equipments Destruction",fontsize=20)
plt.show()

# %% [markdown]
# **Insights:**
#
# * Among the destroyed field equipments **38.12%** is **Armored Personnel Carrier**, **29.12%** is **Vehicle And Fuel Tank**, **18.07%** is **Tank**, **10.75%** is **Field Artillery**, **2.57%** is **Multiple Rocket Launcher** and **1.36%** is **Anti Aircraft Warfare**

# %% [markdown]
# <a id="12"></a>
# # <p style="padding:10px;background-color:#3d11ed;margin:0;color:#e9c46a;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Daywise Destruction</p>

# %%
print("Daywise destruction of air, water and field equipments altogether :\n")

_, axs = plt.subplots(figsize=(20,8))
plt.tight_layout(pad=4.0)

sns.lineplot(x=air_data.index,y=air_data[["aircraft","helicopter","drone","mobile SRBM system"]].sum(axis=1),ax=axs,color=palette[6])
sns.lineplot(x=water_data.index,y=water_data[["naval ship","cruise missiles"]].sum(axis=1),ax=axs,color=palette[1])
sns.lineplot(x=field_data.index,y=field_data[["tank","APC","MRL","field artillery","anti-aircraft warfare","vehicles and fuel tanks"]].sum(axis=1),ax=axs,color=palette[5])

axs.set_title("\nWar Equipments Destruction\n",fontsize=25)
axs.set_xlabel("\nDays",fontsize=20)
axs.set_ylabel("Quantity",fontsize=20)
axs.legend(["Air Equipment", "Water Equipment", "Field Equipment"],title="Category",edgecolor = "#1c1c1c")
sns.despine(left=True, bottom=True)

plt.show()
# Out:
# Daywise destruction of air, water and field equipments altogether :

# %% [markdown]
# <a id="13"></a>
# # <p style="padding:10px;background-color:#3d11ed;margin:0;color:#e9c46a;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Cumulative Destruction</p>

# %%
print("Daywise cumulative destruction of air, water and field equipments altogether :\n")

_, axs = plt.subplots(figsize=(20,8))
plt.tight_layout(pad=4.0)

sns.lineplot(x=air_data.index,y=air_data[["aircraft","helicopter","drone","mobile SRBM system"]].sum(axis=1).cumsum(axis=0),ax=axs,color=palette[6])
sns.lineplot(x=water_data.index,y=water_data[["naval ship","cruise missiles"]].sum(axis=1).cumsum(axis=0),ax=axs,color=palette[1])
sns.lineplot(x=field_data.index,y=field_data[["tank","APC","MRL","field artillery","anti-aircraft warfare","vehicles and fuel tanks"]].sum(axis=1).cumsum(axis=0),ax=axs,color=palette[5])

axs.set_title("\nWar Equipments Destruction\n",fontsize=25)
axs.set_xlabel("Days",fontsize=20)
axs.set_ylabel("Quantity",fontsize=20)
axs.legend(["Air Equipment", "Water Equipment", "Field Equipment"],title="Category",edgecolor = "#1c1c1c")
sns.despine(left=True, bottom=True)

plt.show()
# Out:
# Daywise cumulative destruction of air, water and field equipments altogether :

# %% [markdown]
# <a id="14"></a>
# # <p style="padding:10px;background-color:#3d11ed;margin:0;color:#e9c46a;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Overall Destruction</p>

# %%
plt.subplots(figsize=(12, 12))

labels = "Field Equipment","Air Equipment","Water Equipment" 
size = 0.5

wedges, texts, autotexts = plt.pie([field_data[["tank","APC","MRL","field artillery","anti-aircraft warfare","vehicles and fuel tanks"]].sum(axis=1).sum(axis=0),
                                    air_data[["aircraft","helicopter","drone","mobile SRBM system"]].sum(axis=1).sum(axis=0),
                                    water_data[["naval ship","cruise missiles"]].sum(axis=1).sum(axis=0)],
                                    explode = (0,0,0),
                                    textprops=dict(size= 20, color= "white"),
                                    autopct="%.2f%%", 
                                    pctdistance = 0.75,
                                    radius=1, 
                                    colors = ["#bc4749","#585123","#eec170"], 
                                    # labels = labels, # labeldistance = 1.05,
                                    shadow = True,
                                    wedgeprops=dict(width = size, edgecolor = "#1c1c1c", linewidth = 4),
                                    startangle = 20)

plt.legend(wedges, labels, title="Category",loc="center left",bbox_to_anchor=(1, 0, 0.5, 1), edgecolor = "#1c1c1c")
plt.title("\nOverall Equipments Destruction",fontsize=20)
plt.show()

# %% [markdown]
# **Insights:**
#
# * Among the destroyed equipments **88.07%** is **Field Equipment**, **10.16%** is **Air Equipment** and **1.78%** is **Water Equipment**

# %% [markdown]
# <a id="15"></a>
# # <p style="padding:10px;background-color:#3d11ed;margin:0;color:#e9c46a;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Correlation Map</p>

# %%
# cmap_palette = ["#1E2328","#2A2E34","#3B3F46","#7C7C7C","#FED053","#FFC300","#F5B301","#F48C06","#E85D04","#DC2F02","#D00000","#9D0208","#8c0034","#900C3F","#7e002f","#680840","#600840","#580838","#480838"]
cmap_palette = ["#1E2328","#2A2E34","#3B3F46","#7C7C7C","#FED053","#FFC300","#F5B301","#F48C06","#E85D04","#DC2F02","#D00000","#9D0208"]

sns.palplot(sns.color_palette(cmap_palette))
plt.show()

# %%
plt.subplots(figsize =(14, 12))

sns.heatmap(war_data.drop(columns="day").corr(), cmap = cmap_palette, square=True, cbar_kws=dict(shrink =.95), 
            annot=True, vmin=-1, vmax=1, linewidths=0.1,linecolor='white',annot_kws=dict(fontsize =12))
plt.title("Pearson Correlation Of Features\n", fontsize=25)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# <a id="16"></a>
# # <p style="padding:10px;background-color:#3d11ed;margin:0;color:#e9c46a;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Thank You</p>
#
#
# <p>
#
#
#
#
# </p>

# %%
import base64
import pandas as pd
from IPython.display import HTML

def create_download_link( df, title = "Download CSV file", filename = "russia_losses_personnel.csv"):
    csv = df.to_csv()
    b64 = base64.b64encode(csv.encode())
    payload = b64.decode()
    html = '<a download="{filename}" href="data:text/csv;base64,{payload}" target="_blank">{title}</a>'
    html = html.format(payload=payload,title=title,filename=filename)
    return HTML(html)



create_download_link(personnel_dataset)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [1], line 1
# ----> 1 equipment_dataset.to_csv("new.csv",sep='?')
#
# NameError: name 'equipment_dataset' is not defined
